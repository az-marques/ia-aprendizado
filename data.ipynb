# %%
import pandas as pd

def load_data():
    return pd.read_csv("datasets/ckd.csv")

# %%
data = load_data()
data.head()
# Out:
#    Sex  Age  Systolic_Pressure   BMI  CKD_Cause  Hemoglobin  Albumin  \
# 0    2   74              120.0  23.1          2        12.0      4.0
# 1    1   39              121.0  31.7          3        15.0      4.7
# 2    1   74              143.0  24.6          2        10.9      3.8
# 3    1   57              139.0  28.5          2        15.9      4.8
# 4    1   32              154.0  24.6          4        14.4      4.4
#
#    Creatinine   eGFR  CKD_Stage  ...  Occult_Blood_in_Urine  \
# 0        1.20  34.15          3  ...                    0.0
# 1        1.31  50.45          3  ...                    0.0
# 2        4.95   9.80          5  ...                    0.0
# 3        0.84  73.57          2  ...                    0.0
# 4        0.87  83.56          2  ...                    0.0
#
#    Protein_Creatinine_Ratio  UPCR_Severity  Hypertension  Previous_CVD  \
# 0                      1.25            3.0             1             0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1138 entries, 0 to 1137
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Sex                       1138 non-null   int64
#  1   Age                       1138 non-null   int64
#  2   Systolic_Pressure         1120 non-null   float64
#  3   BMI                       1001 non-null   float64
#  4   CKD_Cause                 1138 non-null   int64
#  5   Hemoglobin                1136 non-null   float64
#  6   Albumin                   1126 non-null   float64
#  7   Creatinine                1138 non-null   float64
#  8   eGFR                      1138 non-null   float64
#  9   CKD_Stage                 1138 non-null   int64
#  10  CKD_Risk                  1050 non-null   float64
#  11  Dipstick_Proteinuria      1122 non-null   float64
#  12  Proteinuria               1122 non-null   float64
# ...

# %%
data.describe()
# Out:
#                Sex          Age  Systolic_Pressure          BMI    CKD_Cause  \
# count  1138.000000  1138.000000         1120.00000  1001.000000  1138.000000
# mean      1.304042    67.578207          139.79375    23.735664     2.260984
# std       0.460203    13.672753           22.45435     4.033175     1.010711
# min       1.000000    21.000000           66.00000    14.200000     1.000000
# 25%       1.000000    61.000000          125.00000    21.000000     1.000000
# 50%       1.000000    70.000000          138.00000    23.300000     2.000000
# 75%       2.000000    77.000000          152.00000    25.800000     3.000000
# max       2.000000    94.000000          234.00000    44.200000     4.000000
#
#         Hemoglobin      Albumin   Creatinine         eGFR    CKD_Stage  ...  \
# count  1136.000000  1126.000000  1138.000000  1138.000000  1138.000000  ...
# mean     11.938644     3.843073     2.269411    32.712566     3.603691  ...
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
data.hist(bins=50, figsize=(20,15))
plt.show()

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(data, test_size=0.2, random_state=42)
data = train_set.copy()

# %%
corr_matrix = data.corr()
corr_matrix["CKD_Stage"].sort_values(ascending=False)
# Out:
# CKD_Stage                   1.000000
# CKD_Risk                    0.965165
# Creatinine                  0.778114
# CKD_Progression             0.476690
# UPCR_Severity               0.386579
# Dipstick_Proteinuria        0.353943
# Proteinuria                 0.333360
# Diuretics                   0.316478
# Protein_Creatinine_Ratio    0.309211
# Hypertension                0.234167
# Calcium_Channel_Blocker     0.230491
# Diabetes                    0.217154
# Age                         0.197993
# RAAS_Inhibitor              0.175130
# Previous_CVD                0.140120
# Sex                         0.115875
# Systolic_Pressure           0.106742
# BMI                         0.044642
# Occult_Blood_in_Urine       0.023889
# CKD_Cause                  -0.226669
# Albumin                    -0.281295
# Hemoglobin                 -0.581256
# eGFR                       -0.919079
# Name: CKD_Stage, dtype: float64

# %%
from pandas.plotting import scatter_matrix
attributes = ["CKD_Stage", "Creatinine", "Hemoglobin",
"eGFR"]
scatter_matrix(data[attributes], figsize=(12, 8))
# Out:
# array([[<Axes: xlabel='CKD_Stage', ylabel='CKD_Stage'>,
#         <Axes: xlabel='Creatinine', ylabel='CKD_Stage'>,
#         <Axes: xlabel='Hemoglobin', ylabel='CKD_Stage'>,
#         <Axes: xlabel='eGFR', ylabel='CKD_Stage'>],
#        [<Axes: xlabel='CKD_Stage', ylabel='Creatinine'>,
#         <Axes: xlabel='Creatinine', ylabel='Creatinine'>,
#         <Axes: xlabel='Hemoglobin', ylabel='Creatinine'>,
#         <Axes: xlabel='eGFR', ylabel='Creatinine'>],
#        [<Axes: xlabel='CKD_Stage', ylabel='Hemoglobin'>,
#         <Axes: xlabel='Creatinine', ylabel='Hemoglobin'>,
#         <Axes: xlabel='Hemoglobin', ylabel='Hemoglobin'>,
#         <Axes: xlabel='eGFR', ylabel='Hemoglobin'>],
#        [<Axes: xlabel='CKD_Stage', ylabel='eGFR'>,
#         <Axes: xlabel='Creatinine', ylabel='eGFR'>,
#         <Axes: xlabel='Hemoglobin', ylabel='eGFR'>,
#         <Axes: xlabel='eGFR', ylabel='eGFR'>]], dtype=object)

# %%
corr_matrix["CKD_Progression"].sort_values(ascending=False)
# Out:
# CKD_Progression             1.000000
# Creatinine                  0.542354
# CKD_Risk                    0.524342
# Protein_Creatinine_Ratio    0.482822
# CKD_Stage                   0.476690
# Dipstick_Proteinuria        0.470931
# UPCR_Severity               0.427724
# Proteinuria                 0.384588
# Diabetes                    0.237281
# Diuretics                   0.205536
# Systolic_Pressure           0.196366
# Calcium_Channel_Blocker     0.161780
# Occult_Blood_in_Urine       0.136456
# Hypertension                0.134459
# RAAS_Inhibitor              0.114902
# BMI                         0.079780
# Sex                         0.031230
# Previous_CVD               -0.003431
# Age                        -0.082151
# CKD_Cause                  -0.262235
# Hemoglobin                 -0.345952
# Albumin                    -0.346761
# eGFR                       -0.437825
# Name: CKD_Progression, dtype: float64

# %%
from pandas.plotting import scatter_matrix
attributes = ["CKD_Progression", "Creatinine", "Protein_Creatinine_Ratio",
"Dipstick_Proteinuria"]
scatter_matrix(data[attributes], figsize=(12, 8))
